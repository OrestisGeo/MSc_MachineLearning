# %% [markdown]
# <a href="https://colab.research.google.com/github/OrestisGeo/MSc_MachineLearning/blob/main/ML_Exercise_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Machine Learning - Exercise 9**

# %% [markdown]
# Installing libraries:

# %%
# !pip install swig
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 32.0 MB/s eta 0:00:00
# ...

# %%
# !pip install gymnasium[box2d]
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 52.7 MB/s eta 0:00:00
# ...

# %%
# !pip install ray[rllib]
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.5/43.5 kB 3.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 965.4/965.4 kB 35.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 220.9/220.9 kB 22.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 10.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 78.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.4/72.4 MB 11.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: ormsgpack
#     Found existing installation: ormsgpack 1.12.1
#     Uninstalling ormsgpack-1.12.1:
#       Successfully uninstalled ormsgpack-1.12.1
#   Attempting uninstall: gymnasium
#     Found existing installation: gymnasium 1.2.3
#     Uninstalling gymnasium-1.2.3:
#       Successfully uninstalled gymnasium-1.2.3
# ...

# %%
# !pip install renderlab

# %% [markdown]
# Question 3:

# %% [markdown]
# - Η συνάρτηση reset() επαναφέρει το περιβάλλον σε μια αρχική εσωτερική κατάσταση. Επίσης επιστρέφει την κατάσταση του αρχικού observation και το dictionary που περιέχει συμπληρωματικές πληροφορίες για το observation.
# Η συνάρτηση reset συνίσταται να καλείται μια φορά μετά την αρχικοποίηση και ποτέ ξανά.
#
# - Η συνάρτηση step() τρέχει ένα action το οποίο παίρνει ως παράμετρο, και επιστρέφει το επόμενο observation. Επίσης επιστρέφει το reward του action που εκτελέστηκε, αν ο agent έχει φτάσει στην τελική κατάσταση, και κάποιες επιπλέον πληροφορίες (info).
#
# - Η συνάρτηση render() υπολογίζει τα rendered frames με βάση το render mode κατά την αρχικοποίηση του περιβάλλοντος.

# %% [markdown]
# Question 4:
#
# ```
# # This is formatted as code
# ```

# %%
import gymnasium as gym

# Create the environment
env = gym.make("LunarLander-v3")

# Print spaces
print("Observation Space:", env.observation_space)
print("Action Space:", env.action_space)

print("Observation shape:", env.observation_space.shape)
print("Number of actions:", env.action_space.n)

env.close()
# Out:
# Observation Space: Box([ -2.5        -2.5       -10.        -10.         -6.2831855 -10.
#   -0.         -0.       ], [ 2.5        2.5       10.        10.         6.2831855 10.
#   1.         1.       ], (8,), float32)
# Action Space: Discrete(4)
# Observation shape: (8,)
# Number of actions: 4

# %% [markdown]
#  Σύμφωνα με το documentation:
#
#  Το Action Space είναι 4 δυνατές διακριτές ενέργειες οι οποίες είναι οι εξής:
#
#   0: do nothing,  1: fire left orientation engine, 2: fire main engine, 3: fire right orientation engine
#
#
#
#
# To Observation Space είναι ένα διάνυσμα 8 διαστάσεωνγ που αποτελείται από τις συντεταγμένες του σκάφους στους άξονες x και y, τις γραμμικές του ταχύτητες στους άξονες x και y, την γωνία προσανατολισμού του, την γωνιακή του ταχύτητα, καθώς και δύο δυαδικές μεταβλητές που δείχνουν αν κάθε ένα από τα δύο "πόδια" του βρίσκεται σε επαφή με το έδαφος ή όχι.

# %% [markdown]
# Question 5:

# %%
import matplotlib.pyplot as plt
import gymnasium as gym
import ray
from ray.rllib.algorithms.ppo import PPOConfig
import os

# %%
import gymnasium as gym

env = gym.make("LunarLander-v3")
print(env.observation_space)
print(env.action_space)
env.close()
# Out:
# Box([ -2.5        -2.5       -10.        -10.         -6.2831855 -10.
#   -0.         -0.       ], [ 2.5        2.5       10.        10.         6.2831855 10.
#   1.         1.       ], (8,), float32)
# Discrete(4)

# %%
os.environ["RAY_DEDUP_LOGS"] = "0"
os.environ["RAY_ACCEL_ENV_VAR_OVERRIDE_ON_ZERO"] = "0"

ray.shutdown()
ray.init(ignore_reinit_error=True)

config = PPOConfig()
config.use_critic = True
config.use_gae = True
config.lambda_ = 0.95
config.use_kl_loss = True
config.sgd_minibatch_size = 32
config.num_sgd_iter = 30
config.shuffle_sequences = True
config.vf_loss_coeff = 0.5
config.entropy_coeff = 0.001
config.clip_param = 0.2
config.framework('tf')

agent = config.environment("LunarLander-v3").env_runners(num_env_runners=0).build()
agent.get_policy().model.base_model.summary(expand_nested=True)
# Out:
# 2026-01-14 20:10:04,483	INFO worker.py:2007 -- Started a local Ray instance.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-1811755746.py in <cell line: 0>()
#      18 config.framework('tf')
#      19
# ---> 20 agent = config.environment("LunarLander-v3").env_runners(num_env_runners=0).build()
#      21 agent.get_policy().model.base_model.summary(expand_nested=True)
#
# /usr/local/lib/python3.12/dist-packages/ray/_common/deprecation.py in _ctor(*args, **kwargs)
#     133                 )
#     134             # Call the deprecated method/function.
# --> 135             return obj(*args, **kwargs)
#     136
#     137         # Return the patched class method/function.
#
# /usr/local/lib/python3.12/dist-packages/ray/rllib/algorithms/algorithm_config.py in build(self, *args, **kwargs)
#    5877     @Deprecated(new="AlgorithmConfig.build_algo", error=False)
# ...

# %%
Δεν μπορώ να το κάνω να τρέξει. Μου λέει ότι το framework tf είναι deprecated, και ότι το tf2 δεν είναι supported.
