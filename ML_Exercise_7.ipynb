# %% [markdown]
# <a href="https://colab.research.google.com/github/OrestisGeo/MSc_MachineLearning/blob/Exercise_7/ML_Exercise_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Machine Learning - Exercise 7**

# %% [markdown]
# Question 1:

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import files
import numpy as np
